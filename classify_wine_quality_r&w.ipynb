# %% [markdown]
# <a href="https://colab.research.google.com/github/git933/Deep_Learning/blob/main/classify_wine_quality_r%26w.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # red

# %% [markdown]
# logistic regression

# %%
import numpy as np
import pandas as pd

from sklearn import datasets
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
# load dataset from sklearn
wine_red = datasets.load_wine()

# %%
print(wine_red.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %%
wine_red.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
df = pd.DataFrame(wine_red.data, columns = wine_red.feature_names)
df['target'] = wine_red.target

df.head()
# Out:
#    alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  target
# 0    14.23        1.71  2.43  ...                          3.92   1065.0       0
# 1    13.20        1.78  2.14  ...                          3.40   1050.0       0
# 2    13.16        2.36  2.67  ...                          3.17   1185.0       0
# 3    14.37        1.95  2.50  ...                          3.45   1480.0       0
# 4    13.24        2.59  2.87  ...                          2.93    735.0       0
#
# [5 rows x 14 columns]

# %%
df.tail()
# Out:
#      alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  target
# 173    13.71        5.65  2.45  ...                          1.74    740.0       2
# 174    13.40        3.91  2.48  ...                          1.56    750.0       2
# 175    13.27        4.28  2.26  ...                          1.56    835.0       2
# 176    13.17        2.59  2.37  ...                          1.62    840.0       2
# 177    14.13        4.10  2.74  ...                          1.60    560.0       2
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (178, 14)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      alcohol  malic_acid   ash  ...  od280/od315_of_diluted_wines  proline  target
# 0      14.23        1.71  2.43  ...                          3.92   1065.0       0
# 1      13.20        1.78  2.14  ...                          3.40   1050.0       0
# 2      13.16        2.36  2.67  ...                          3.17   1185.0       0
# 3      14.37        1.95  2.50  ...                          3.45   1480.0       0
# 4      13.24        2.59  2.87  ...                          2.93    735.0       0
# ..       ...         ...   ...  ...                           ...      ...     ...
# 173    13.71        5.65  2.45  ...                          1.74    740.0       2
# 174    13.40        3.91  2.48  ...                          1.56    750.0       2
# 175    13.27        4.28  2.26  ...                          1.56    835.0       2
# 176    13.17        2.59  2.37  ...                          1.62    840.0       2
# ...

# %%
print(df.iloc[:, -1].value_counts())
# Out:
# 1    71
# 0    59
# 2    48
# Name: target, dtype: int64

# %%
x_data = wine_red.data
y_data = wine_red.target
print(x_data.shape)
print(y_data.shape)
# Out:
# (178, 13)
# (178,)

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x_data, y_data, test_size = 0.33)

estimator = LogisticRegression(penalty = 'l2', C = 1.0, max_iter = 100, tol = 0.0001)
estimator.fit(x_train, y_train)

y_predict = estimator.predict(x_train)
score = metrics.accuracy_score(y_train, y_predict)
print(score)

y_predict = estimator.predict(x_test)
score = metrics.accuracy_score(y_test, y_predict)
print(score)
# Out:
# 0.9663865546218487
# 0.9152542372881356
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# ---

# %% [markdown]
# # white

# %%
import numpy as np
import pandas as pd

from sklearn import datasets
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# load gdrive file
df1 = pd.read_csv('/content/drive/MyDrive/DeepLearning/winequality-white.csv', sep = ';')

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.0              0.27         0.36  ...       0.45      8.8        6
# 1               6.3              0.30         0.34  ...       0.49      9.5        6
# 2               8.1              0.28         0.40  ...       0.44     10.1        6
# 3               7.2              0.23         0.32  ...       0.40      9.9        6
# 4               7.2              0.23         0.32  ...       0.40      9.9        6
# ...             ...               ...          ...  ...        ...      ...      ...
# 4893            6.2              0.21         0.29  ...       0.50     11.2        6
# 4894            6.6              0.32         0.36  ...       0.46      9.6        5
# 4895            6.5              0.24         0.19  ...       0.46      9.4        6
# 4896            5.5              0.29         0.30  ...       0.38     12.8        7
# ...

# %%
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        6
# 1            6.3              0.30         0.34  ...       0.49      9.5        6
# 2            8.1              0.28         0.40  ...       0.44     10.1        6
# 3            7.2              0.23         0.32  ...       0.40      9.9        6
# 4            7.2              0.23         0.32  ...       0.40      9.9        6
#
# [5 rows x 12 columns]

# %%
df1.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 4893            6.2              0.21         0.29  ...       0.50     11.2        6
# 4894            6.6              0.32         0.36  ...       0.46      9.6        5
# 4895            6.5              0.24         0.19  ...       0.46      9.4        6
# 4896            5.5              0.29         0.30  ...       0.38     12.8        7
# 4897            6.0              0.21         0.38  ...       0.32     11.8        6
#
# [5 rows x 12 columns]

# %%
df1.shape
# Out:
# (4898, 12)

# %%
df1.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    4898.000000       4898.000000  ...  4898.000000  4898.000000
# mean        6.854788          0.278241  ...    10.514267     5.877909
# std         0.843868          0.100795  ...     1.230621     0.885639
# min         3.800000          0.080000  ...     8.000000     3.000000
# 25%         6.300000          0.210000  ...     9.500000     5.000000
# 50%         6.800000          0.260000  ...    10.400000     6.000000
# 75%         7.300000          0.320000  ...    11.400000     6.000000
# max        14.200000          1.100000  ...    14.200000     9.000000
#
# [8 rows x 12 columns]

# %%
df1.keys()
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df1.iloc[:, -1].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
x_data1 = df1.iloc[:, :-1]
y_data1 = df1.iloc[:, -1]
print(x_data1.shape)
print(y_data1.shape)

x_data1 = x_data1.values
y_data1 = y_data1.values
# Out:
# (4898, 11)
# (4898,)

# %%
df1.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x_data1, y_data1, test_size = 0.3)

estimator = LogisticRegression(penalty = 'l2', C = 0.7, max_iter = 100, tol = 0.0001)
estimator.fit(x_train, y_train)

y_predict = estimator.predict(x_train)
score = metrics.accuracy_score(y_train, y_predict)
print(score)

y_predict = estimator.predict(x_test)
score = metrics.accuracy_score(y_test, y_predict)
print(score)
# Out:
# 0.4684947491248541
# 0.45714285714285713
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# ---

# %% [markdown]
# # red + white

# %%
# importing libraries

import numpy as np
import pandas as pd

from sklearn import datasets
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
wine_red = pd.read_csv('/content/drive/MyDrive/DeepLearning/winequality-red.csv', sep = ';')
wine_white = pd.read_csv('/content/drive/MyDrive/DeepLearning/winequality-white.csv', sep = ';')

# %%
wine_red['result'] = 0
wine_white['result'] = 1

# %%
wine = pd.concat([wine_red, wine_white])

# %%
train, test = train_test_split(wine, test_size = 0.2)
train_data = train.drop(columns = 'result')
train_targets = train.result

test_data = test.drop(columns = 'result')
test_targets = test.result

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from keras.models import Sequential
from keras.layers import Activation, Dense

model = Sequential()
model.add(Dense(1, input_dim = train_data.shape[1], activation = 'sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
model.fit(train_data, train_targets, batch_size = 100, epochs = 500, shuffle = False)
# Out:
# Epoch 1/500
# 52/52 [==============================] - 14s 1ms/step - loss: 57.6079 - binary_accuracy: 0.2536
# Epoch 2/500
# 52/52 [==============================] - 0s 1ms/step - loss: 49.4589 - binary_accuracy: 0.2536
# Epoch 3/500
# 52/52 [==============================] - 0s 1ms/step - loss: 41.3357 - binary_accuracy: 0.2536
# Epoch 4/500
# 52/52 [==============================] - 0s 1ms/step - loss: 33.2212 - binary_accuracy: 0.2535
# Epoch 5/500
# 52/52 [==============================] - 0s 1ms/step - loss: 25.1195 - binary_accuracy: 0.2520
# Epoch 6/500
# 52/52 [==============================] - 0s 1ms/step - loss: 17.0805 - binary_accuracy: 0.2368
# Epoch 7/500
# 52/52 [==============================] - 0s 1ms/step - loss: 9.2770 - binary_accuracy: 0.1937
# Epoch 8/500
# 52/52 [==============================] - 0s 1ms/step - loss: 2.9902 - binary_accuracy: 0.2807
# Epoch 9/500
# 52/52 [==============================] - 0s 1ms/step - loss: 1.2789 - binary_accuracy: 0.6180
# ...

# %%
model.evaluate(test_data, test_targets)
# Out:
# 41/41 [==============================] - 0s 986us/step - loss: 0.0703 - binary_accuracy: 0.9738
# [0.0703246146440506, 0.9738461375236511]
